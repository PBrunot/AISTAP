# %%
import matplotlib.pyplot as plt

risultati = { 1:1,
              2:3,
              3:4,
              4:0,
              5:0,
              6:0}

plt.bar(risultati.keys(), risultati.values(), 1, color='g')
plt.show()
